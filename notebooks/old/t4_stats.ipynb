# %%
# !pip install spacy --upgrade
# Out:
# Requirement already satisfied: spacy in d:\anaconda3\lib\site-packages (2.3.5)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# textacy 0.10.1 requires spacy<3.0.0,>=2.2.0, but you have spacy 3.1.1 which is incompatible.
# en-core-web-sm 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.1.1 which is incompatible.
# en-core-web-lg 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.1.1 which is incompatible.
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: You are using pip version 21.1.3; however, version 21.2.2 is available.
# You should consider upgrading via the 'd:\anaconda3\python.exe -m pip install --upgrade pip' command.
# Collecting spacy
#   Using cached spacy-3.1.1-cp38-cp38-win_amd64.whl (12.0 MB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Collecting spacy-legacy<3.1.0,>=3.0.7
#   Using cached spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in d:\anaconda3\lib\site-packages (from spacy) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from spacy) (21.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from spacy) (3.0.5)
# Collecting thinc<8.1.0,>=8.0.8
#   Using cached thinc-8.0.8-cp38-cp38-win_amd64.whl (1.0 MB)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda3\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in d:\anaconda3\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in d:\anaconda3\lib\site-packages (from spacy) (2.0.4)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Using cached pydantic-1.8.2-cp38-cp38-win_amd64.whl (2.0 MB)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in d:\anaconda3\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from spacy) (2.11.2)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from spacy) (50.3.1.post20201107)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in d:\anaconda3\lib\site-packages (from spacy) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda3\lib\site-packages (from spacy) (4.49.0)
# Requirement already satisfied: numpy>=1.15.0 in d:\anaconda3\lib\site-packages (from spacy) (1.19.2)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.6.0-py3-none-any.whl (42 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from spacy) (2.26.0)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Collecting smart-open<6.0.0,>=5.0.0
#   Using cached smart_open-5.1.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.7.4.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in d:\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Installing collected packages: smart-open, pydantic, thinc, spacy-legacy, pathy, spacy
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.5
#     Uninstalling thinc-7.4.5:
#       Successfully uninstalled thinc-7.4.5
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.3.5
#     Uninstalling spacy-2.3.5:
#       Successfully uninstalled spacy-2.3.5
# Successfully installed pathy-0.6.0 pydantic-1.8.2 smart-open-5.1.0 spacy-3.1.1 spacy-legacy-3.0.8 thinc-8.0.8

# %%
import spacy
spacy.__version__
# Out:
# '3.1.1'

# %%
# !python -m spacy download ru_core_news_sm
# Out:
# Collecting ru-core-news-sm==3.1.0
# 2021-08-02 11:55:34.748406: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library cudart64_101.dll
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qdm (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (d:\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\anaconda3\lib\site-packages)
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.1.0/ru_core_news_sm-3.1.0-py3-none-any.whl (16.1 MB)
# Collecting pymorphy2>=0.9
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in d:\anaconda3\lib\site-packages (from ru-core-news-sm==3.1.0) (3.1.1)
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (50.3.1.post20201107)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (3.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (0.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (21.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.4.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (0.7.4)
# Requirement already satisfied: numpy>=1.15.0 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (1.19.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (8.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.0.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (0.3.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (1.8.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (4.49.0)
# Requirement already satisfied: jinja2 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.26.0)
# Requirement already satisfied: pathy>=0.3.5 in d:\anaconda3\lib\site-packages (from spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (0.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in d:\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (5.1.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (3.7.4.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2020.6.20)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.0.3)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in d:\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda3\lib\site-packages (from jinja2->spacy<3.2.0,>=3.1.0->ru-core-news-sm==3.1.0) (1.1.1)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13709 sha256=5aa6ae6cf40ae1c08b79d77ad87d4ba68cd60e53beca62954eccd971bdf4357d
#   Stored in directory: c:\users\altsoph\appdata\local\pip\cache\wheels\56\ea\58\ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2, ru-core-news-sm
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844 ru-core-news-sm-3.1.0
# [+] Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# WARNING: You are using pip version 21.1.3; however, version 21.2.2 is available.
# You should consider upgrading via the 'd:\Anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import spacy
from spacy.lang.ru.examples import sentences 

nlp = spacy.load("ru_core_news_sm")
doc = nlp(sentences[0])
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Apple рассматривает возможность покупки стартапа из Соединённого Королевства за $1 млрд
# Apple PROPN nsubj
# рассматривает VERB ROOT
# возможность NOUN obj
# покупки NOUN nmod
# стартапа NOUN nmod
# из ADP case
# Соединённого ADJ amod
# Королевства PROPN nmod
# за ADP case
# $ SYM nmod
# 1 NUM appos
# млрд NOUN punct

# %%
import csv

cancel = []
cause  = []
rels = []
same = []

records = []
with open("ru_news_cause_v1.tsv", "r", encoding='utf-8') as r:
    reader = csv.reader(r, delimiter="\t")
    header = next(reader)
    for row in reader:
        r = dict(zip(header, row))
        if float(r["confidence"]) < 0.69:
            continue
        result = r["result"]
        mapping = {
#             "bad": 0,
            "rel": 0,
            "same": 0,
            "left_right_cause": 0,
            "left_right_cancel": 1,
            "right_left_cause": 0,
            "right_left_cancel": 1
        }
        if result not in mapping:
            continue
        if result.startswith('right'):
            r['left_title'], r['right_title'] = r['right_title'], r['left_title']
        if result.endswith('cause'):
            cause.append( (r['left_title'], r['right_title']) )
        elif result.endswith('cancel'):
            cancel.append( (r['left_title'], r['right_title']) )
        elif result.endswith('same'):
            same.append( (r['left_title'], r['right_title']) )
        elif result.endswith('rel'):
            rels.append( (r['left_title'], r['right_title']) )

        r["label"] = mapping[result]
        records.append(r)

# %%
def get_verbs_lemmed(s):
    doc = nlp(s)
    negation_tokens = [tok for tok in doc if tok.dep_ == 'neg' or tok.lemma_ in ('не','передумать',
                            'отменить','отказаться')]
    negated_tokens = [child.lemma_ for token in negation_head_tokens for child in token.children]
    verbs = []
    for token in doc:
        if token.is_stop: continue
        if token.pos_ == 'VERB':
            if token.lemma_ in negated_tokens:
                verbs.append( 'не_'+token.lemma_ )
            else:
                verbs.append( token.lemma_ )
    return tuple(verbs)

def pairs2verbs(l):
    return tuple( [ (get_verbs_lemmed(s1), get_verbs_lemmed(s2)) for s1, s2 in l ] )

cancel_verbs = pairs2verbs(cancel)
cause_verbs = pairs2verbs(cause)
rels_verbs = pairs2verbs(rels)
same_verbs = pairs2verbs(same)
cancel_verbs
# Out:
# ((('скончаться',), ('скончаться',)),
#  (('не_вернуться',), ('не_вернуться', 'отправиться')),
#  (('спрогнозировать',), ('опровергнуть',)),
#  (('заболеть',), ('подтвердиться',)),
#  (('начаться',), ('опровергнуть',)),
#  (('объяснить',), ('опровергнуть',)),
#  (('подать',), ('подать',)),
#  (('обязать', 'устанавливать'), ('решить', 'перенести')),
#  (('обвинить',), ('опровергнуть',)),
#  (('стать', 'не_вернуться'), ('опровергнуть',)),
#  (('стать', 'закрыть'), ('опровергнуть',)),
#  (('отказаться', 'покидать'), ('не_вернуться',)),
#  (('госпитализировать',), ('опровергнуть',)),
#  (('предложить', 'хранить'), ('отказаться', 'хранить')),
#  (('предупредить',), ('опровергнуть',)),
#  (('задержать',), ('опровергнуть',)),
#  (('приостановить',), ('снять',)),
#  (('подать',), ('передумать', 'судиться')),
#  (('стать',), ('опровергнуть',)),
#  (('появиться', 'спасти'), ('опровергнуть',)),
#  (('рассказать',), ('опровергнуть',)),
#  (('назвать',), ('опровергнуть',)),
#  (('покончить',), ('опровергнуть',)),
#  (('спрогнозировать',), ('опровергнуть',)),
#  (('заявить',), ('увеличиться',)),
#  (('оставить',), ('опровергнуть',)),
#  (('отказаться', 'выступать'), ('выступать', 'опровергнуть')),
#  (('госпитализировать',), ('опровергнуть',)),
#  (('пропасть',), ('опровергнуть',)),
#  (('стать',), ('опровергнуть',)),
#  (('установить',), ('опровергнуть',)),
#  (('согласиться', 'отдать'), ('опровергнуть',)),
#  (('найти',), ('опровергнуть',)),
#  (('остановить',), ('перезапустить',)),
#  (('стать', 'встретиться'), ('опровергнуть', 'встретиться')),
#  (('сообщить',), ('опровергнуть',)),
#  (('стать',), ('курировавшего', 'опровергнуть')),
#  (('оказаться', 'открыть'), ('опровергнуть',)),
#  (('пойти',), ('опровергнуть',)),
#  (('составить',), ('опровергнуть',)),
#  (('расторгнуть',), ('опровергнуть',)),
#  (('рассказать', 'отдать'), ('опровергнуть', 'отдать')),
#  (('установить',), ('опровергнуть',)),
#  (('рассказать',), ('опровергнуть',)),
#  (('приковать', 'получить'), ('приковать', 'отменить')),
#  (('заразиться',), ('опровергнуть',)),
#  (('захватить',), ('опровергнуть',)),
#  (('захватить', 'пригрозить', 'устроить'), ('опровергнуть',)),
#  (('исчезнуть',), ('найтись',)),
#  (('предложить', 'отказаться'), ('отказаться', 'отказываться')),
#  (('оказаться',), ('убрать',)),
#  (('погибнуть', 'вырасти'), ('погибнуть',)),
#  (('сообщить',), ('не_вернуться',)),
#  (('готовить',), ('выписать',)),
#  (('ввести',), ('опровергнуть',)),
#  (('запланировать', 'обновить'), ('опровергнуть',)),
#  (('закрыть',), ('открыться',)),
#  (('вторгнуться',), ('опровергнуть',)),
#  (('стать',), ('опровергнуть',)),
#  (('отдать', 'заставить', 'ждать'), ('опровергнуть',)),
#  (('пообещать',), ('опровергнуть', 'заключить')),
#  (('уличить',), ('опровергнуть',)),
#  (('закрыться',), ('опровергнуть',)),
#  (('выставить',), ('продать',)),
#  (('задержать',), ('отпустить',)),
#  (('захотеть', 'привиться'), ('привился',)),
#  (('пожаловаться',), ('опровергнуть',)),
#  (('анонсированы',), ('стать',)),
#  (('опальный', 'отказаться'), ('опровергнуть',)),
#  (('приказать', 'прекратить'), ('опровергнуть',)),
#  (('посоветовать', 'сдать'), ('назвать', 'сдать')),
#  (('анонсирована',), ('завершиться',)),
#  (('стать',), ('опровергнуть',)),
#  (('взять',), ('опровергнуть',)),
#  (('пообещать', 'оказать'), ('опровергнуть',)),
#  (('умереть',), ('опровергнуть',)),
#  (('сэкономить',), ('опровергнуть',)),
#  (('открыться',), ('завершиться',)),
#  (('запланировать', 'открыть'), ('опровергнуть',)),
#  (('заявить', 'сбить'), ('опровергнуть', 'упасть')),
#  (('стать',), ('опровергнуть', 'стать')),
#  (('задержать',), ('отменить',)),
#  (('оформлявших', 'удалить'), ('опровергнуть',)),
#  (('погибнуть',), ('погибнуть', 'вырасти')),
#  (('умереть',), ('опровергнуть',)),
#  (('наградить',), ('опровергнуть',)),
#  (('обвинить',), ('опровергнуть',)),
#  (('погибнуть',), ('погибнуть', 'возрасти')),
#  (('линчевать',), ('опровергнуть',)),
#  (('начать', 'штрафовать'), ('отложить',)),
#  (('остановить',), ('остановить',)),
#  (('появиться',), ('опровергнуть',)),
#  (('захотеть',), ('передумать', 'покупать')),
#  (('заявить',), ('опровергнуть',)),
#  (('сообщить',), ('опровергнуть',)),
#  (('проверить',), ('опровергнуть',)),
#  (('подтвердить', 'вылечился'), ('излечиться',)),
#  (('установить', 'ждать'), ('убрать',)),
#  (('умереть',), ('умереть',)),
#  (('сообщить', 'ответить'), ('появиться', 'развеять')),
#  (('дать', 'вылететь'), ('вылететь',)),
#  (('удалить',), ('восстановить',)),
#  (('выявить', 'подтвердить'), ('выявить',)),
#  (('строить', 'пострадать'), ('построить', 'пострадать')),
#  (('проверять',), ('подтвердиться',)),
#  (('искать', 'пропасть'), ('пропасть', 'найти')),
#  (('зафиксировать',), ('заразиться',)),
#  (('выйти',), ('отложить',)),
#  (('стать',), ('попросить', 'верить')),
#  (('возбудить',), ('объявить', 'погибнуть', 'оказаться')),
#  (('изменить',), ('не_вернуться', 'рассказать')),
#  (('задумать', 'ввести'), ('отвергнуть',)),
#  (('заговорить',), ('получить',)),
#  (('заблокировать',), ('снять',)),
#  (('захотеть', 'признать'), ('отказаться', 'признать')),
#  (('решить', 'переехать'), ('переехать',)),
#  (('оказаться',), ('отменить',)),
#  (('раскрыть',), ('договориться', 'снять')),
#  (('поступить',), ('забрать',)),
#  (('раскрыть',), ('оспорить',)),
#  (('высказать',), ('обсудить',)),
#  (('увеличиться',), ('счесть',)),
#  (('перейти',), ('опровергнуть',)),
#  (('расторгнуть',), ('расторгнуть',)),
#  (('погибнуть', 'извлечь'), ('погибнуть',)),
#  (('уйти',), ('продать',)),
#  (('предсказать',), ('отвергнуть', 'отказаться', 'включить')),
#  (('отменить',), ('отменить',)),
#  (('захотеть', 'помешать', 'получить'), ('разрешить', 'оказать')),
#  (('заразить', 'упасть'), ('назвать',)),
#  (('ввести',), ('ввести',)),
#  (('пропасть',), ('пропасть', 'обнаружить')),
#  (('заразившаяся', 'лечиться'), ('вылечиться',)),
#  (('заминировать', 'лечиться'), ('оказаться',)),
#  (('задержать',), ('освободить',)),
#  (('выступить',), ('длиться',)),
#  (('снять', 'забрать'), ('снять', 'отпустить')),
#  (('отключить',), ('пообещать', 'сохранить')),
#  (('взлететь',), ('подешеветь',)),
#  (('приготовиться', 'собирать'), ('показать',)),
#  (('предсказать',), ('опровергнуть',)),
#  (('погибнуть',), ('погибнуть',)),
#  (('вернуть',), ('не_вернуться',)),
#  (('оценить',), ('сообщить',)),
#  (('обвинять', 'отпустить'), ('обвинить', 'вернуть')),
#  (('оказаться',), ('разразиться',)),
#  (('вернуть',), ('вернуть',)),
#  (('госпитализировать',), ('выписать',)),
#  (('стать', 'заразить'), ('вылечиться',)),
#  (('сообщить',), ('стать',)),
#  (('загореться',), ('потушить',)),
#  (('прогреметь',), ('оказаться',)),
#  (('нависнуть',), ('уклониться',)),
#  (('благословить',), ('передумать',)),
#  (('предложить', 'признать'), ('признать',)),
#  (('вырасти',), ('вырасти',)),
#  (('сократить',), ('назвать',)),
#  (('ограничить',), ('снять',)),
#  (('обнаружить',), ('назвать',)),
#  (('погибнуть',), ('возрасти',)),
#  (('направить',), ('оставить',)),
#  (('появиться',), ('сойтись',)))

# %%
from collections import Counter

def verbs2stats(pl):
    left_verbs = []
    right_verbs = []
    same_verbs = []
    pairs_verbs = []
    neg_pairs_verbs = []
    for vv1, vv2 in pl:
        left_verbs.extend(vv1)
        right_verbs.extend(vv2)
        same_verbs.extend(list(set(vv1)&set(vv2)))
        for v1 in vv1:
            for v2 in vv2:
                pairs_verbs.append( (v1,v2) )
                if (v1 in v2 or v2 in v1) and (v1.startswith('не_') or v2.startswith('не_')):
                    neg_pairs_verbs.append( (v1,v2) )
    print('\nleft verbs stats')
    print('\t'+'\n\t'.join(map(str, Counter(left_verbs).most_common(5))))
    print('\nright verbs stats')
    print('\t'+'\n\t'.join(map(str, Counter(right_verbs).most_common(5))))
    print('\nsame verbs stats')
    print('\t'+'\n\t'.join(map(str, Counter(same_verbs).most_common(5))))
    print('\npair verbs stats')
    print('\t'+'\n\t'.join(map(str, Counter(pairs_verbs).most_common(5))))
    print('\nneg pair verbs stats')
    print('\t'+'\n\t'.join(map(str, Counter(neg_pairs_verbs).most_common(5))))
    
    
print('CANCEL')
verbs2stats(cancel_verbs)
print('\nCAUSE')
verbs2stats(cause_verbs)
print('\nREL')
verbs2stats(rels_verbs)
print('\nSAME')
verbs2stats(same_verbs)
# Out:
# CANCEL
#
# left verbs stats
# 	('стать', 11)
# 	('погибнуть', 6)
# 	('сообщить', 5)
# 	('отказаться', 4)
# 	('задержать', 4)
#
# right verbs stats
# 	('опровергнуть', 66)
# 	('погибнуть', 6)
# 	('не_вернуться', 5)
# 	('снять', 5)
# 	('отказаться', 4)
#
# same verbs stats
# 	('погибнуть', 5)
# 	('пропасть', 2)
# 	('признать', 2)
# 	('скончаться', 1)
# 	('не_вернуться', 1)
#
# pair verbs stats
# 	(('стать', 'опровергнуть'), 9)
# 	(('погибнуть', 'погибнуть'), 5)
# 	(('рассказать', 'опровергнуть'), 3)
# 	(('отдать', 'опровергнуть'), 3)
# 	(('спрогнозировать', 'опровергнуть'), 2)
#
# neg pair verbs stats
# 	(('не_вернуться', 'не_вернуться'), 1)
# 	(('вернуть', 'не_вернуться'), 1)
#
# CAUSE
#
# left verbs stats
# 	('умереть', 58)
# 	('задержать', 44)
# 	('найти', 38)
# 	('назвать', 34)
# 	('предложить', 33)
#
# right verbs stats
# 	('отреагировать', 121)
# 	('раскрыть', 115)
# 	('объяснить', 104)
# 	('ответить', 87)
# 	('появиться', 85)
#
# same verbs stats
# 	('задержать', 8)
# 	('назвать', 7)
# 	('обвинить', 6)
# 	('убить', 5)
# 	('пропасть', 5)
#
# pair verbs stats
# 	(('умереть', 'раскрыть'), 17)
# 	(('умереть', 'назвать'), 15)
# 	(('обвинить', 'ответить'), 12)
# 	(('задержать', 'раскрыть'), 10)
# 	(('задержать', 'показать'), 9)
#
# neg pair verbs stats
#
#
# REL
#
# left verbs stats
# 	('назвать', 117)
# 	('рассказать', 77)
# 	('стать', 45)
# 	('заявить', 45)
# 	('раскрыть', 42)
#
# right verbs stats
# 	('назвать', 124)
# 	('рассказать', 74)
# 	('раскрыть', 57)
# 	('стать', 38)
# 	('заявить', 33)
#
# same verbs stats
# 	('назвать', 28)
# 	('рассказать', 11)
# 	('оценить', 8)
# 	('раскрыть', 7)
# 	('погибнуть', 6)
#
# pair verbs stats
# 	(('назвать', 'назвать'), 28)
# 	(('рассказать', 'рассказать'), 11)
# 	(('назвать', 'раскрыть'), 11)
# 	(('назвать', 'рассказать'), 9)
# 	(('оценить', 'оценить'), 8)
#
# neg pair verbs stats
#
#
# SAME
#
# left verbs stats
# 	('назвать', 18)
# 	('стать', 11)
# 	('найти', 9)
# 	('объяснить', 8)
# 	('раскрыть', 8)
#
# right verbs stats
# 	('назвать', 26)
# 	('раскрыть', 12)
# 	('заявить', 9)
# 	('отказаться', 9)
# 	('задержать', 8)
#
# same verbs stats
# 	('назвать', 9)
# 	('запустить', 5)
# 	('погибнуть', 5)
# 	('задержать', 4)
# 	('найти', 4)
#
# pair verbs stats
# 	(('назвать', 'назвать'), 9)
# 	(('запустить', 'запустить'), 5)
# 	(('погибнуть', 'погибнуть'), 5)
# 	(('назвать', 'раскрыть'), 5)
# 	(('задержать', 'задержать'), 4)
#
# neg pair verbs stats
# 	(('не_вернуться', 'не_вернуться'), 1)

# %%
cancel_sim = [ nlp(s1).similarity(nlp(s2)) for s1, s2 in cancel ]
cause_sim = [ nlp(s1).similarity(nlp(s2)) for s1, s2 in cause ]
rels_sim = [ nlp(s1).similarity(nlp(s2)) for s1, s2 in rels ]
same_sim = [ nlp(s1).similarity(nlp(s2)) for s1, s2 in same ]
# Out:
# <ipython-input-42-732bcca40902>:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   cancel_sim = [ nlp(s1).similarity(nlp(s2)) for s1, s2 in cancel ]
# <ipython-input-42-732bcca40902>:2: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   cause_sim = [ nlp(s1).similarity(nlp(s2)) for s1, s2 in cause ]
# <ipython-input-42-732bcca40902>:3: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   rels_sim = [ nlp(s1).similarity(nlp(s2)) for s1, s2 in rels ]
# <ipython-input-42-732bcca40902>:4: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   same_sim = [ nlp(s1).similarity(nlp(s2)) for s1, s2 in same ]

# %%
import numpy as np
import scipy.stats

def stat_tests(sample1,sample2):
    try:
        mw = scipy.stats.mannwhitneyu(sample1,sample2,alternative='two-sided')[1]
    except:
        mw = "nan"
    tt = scipy.stats.ttest_ind(sample1,sample2)[1]
#     print(mw, tt)
    return (float(mw),float(tt))

def compare_similarities(v1, v2):
    ctl_proj = v1
    exp_proj = v2
    print(f'means',np.mean(v1), np.mean(v2))
    print(f'means diff',float(np.mean(ctl_proj)-np.mean(exp_proj)))
    print(f'stat tests', stat_tests(ctl_proj,exp_proj))

for t1,c1 in (('CANCEL', cancel_sim), ('CAUSE', cause_sim), ('RELS', rels_sim), ('SAME', same_sim), ):
    for t2,c2 in (('CANCEL', cancel_sim), ('CAUSE', cause_sim), ('RELS', rels_sim), ('SAME', same_sim), ):
        print(f'{t1} VS {t2}')
        compare_similarities(c1,c2)
        print()
# Out:
# CANCEL VS CANCEL
# means 0.6158656016217712 0.6158656016217712
# means diff 0.0
# stat tests (0.999526793740703, 1.0)
#
# CANCEL VS CAUSE
# means 0.6158656016217712 0.5068351268025454
# means diff 0.10903047481922579
# stat tests (7.537285638532631e-10, 1.2118202710187373e-10)
#
# CANCEL VS RELS
# means 0.6158656016217712 0.46360273362198995
# means diff 0.15226286799978123
# stat tests (7.27080866206627e-18, 7.709113641376996e-20)
#
# CANCEL VS SAME
# means 0.6158656016217712 0.6142281814613949
# means diff 0.0016374201603762684
# stat tests (0.9516471840527773, 0.93228622377382)
#
# CAUSE VS CANCEL
# means 0.5068351268025454 0.6158656016217712
# means diff -0.10903047481922579
# stat tests (7.537285638532631e-10, 1.2118202710187373e-10)
#
# CAUSE VS CAUSE
# means 0.5068351268025454 0.5068351268025454
# means diff 0.0
# stat tests (0.9999793229131883, 1.0)
#
# CAUSE VS RELS
# means 0.5068351268025454 0.46360273362198995
# means diff 0.04323239318055544
# stat tests (5.754558540624688e-09, 2.5133922946659024e-08)
#
# CAUSE VS SAME
# means 0.5068351268025454 0.6142281814613949
# means diff -0.10739305465884952
# stat tests (2.028829314124543e-17, 2.7965001885342817e-18)
#
# RELS VS CANCEL
# means 0.46360273362198995 0.6158656016217712
# means diff -0.15226286799978123
# stat tests (7.27080866206627e-18, 7.709113641376996e-20)
#
# RELS VS CAUSE
# means 0.46360273362198995 0.5068351268025454
# means diff -0.04323239318055544
# stat tests (5.754558540624688e-09, 2.5133922946659024e-08)
#
# RELS VS RELS
# means 0.46360273362198995 0.46360273362198995
# means diff 0.0
# stat tests (0.9999802808865178, 1.0)
#
# RELS VS SAME
# means 0.46360273362198995 0.6142281814613949
# means diff -0.15062544783940496
# stat tests (6.484318977480711e-33, 5.420607867979027e-35)
#
# SAME VS CANCEL
# means 0.6142281814613949 0.6158656016217712
# means diff -0.0016374201603762684
# stat tests (0.9516471840527773, 0.93228622377382)
#
# SAME VS CAUSE
# means 0.6142281814613949 0.5068351268025454
# means diff 0.10739305465884952
# stat tests (2.028829314124543e-17, 2.7965001885342817e-18)
#
# SAME VS RELS
# means 0.6142281814613949 0.46360273362198995
# means diff 0.15062544783940496
# stat tests (6.484318977480711e-33, 5.420607867979027e-35)
#
# SAME VS SAME
# means 0.6142281814613949 0.6142281814613949
# means diff 0.0
# stat tests (0.9998482742368696, 1.0)

# %%
from collections import Counter

def save_gdf(fn, pl):
    nodes = Counter()
    edges = Counter()
    for vv1, vv2 in pl:
        for v1 in vv1:
            nodes.update([v1,])
        for v2 in vv2:
            nodes.update([v2,])
        for v1 in vv1:
            for v2 in vv2:
                edges.update([(v1,v2)])
    with open(fn, 'w', encoding='utf-8') as fh:
        print('nodedef>name VARCHAR,label VARCHAR,cnt DOUBLE', file=fh)
        for n, c in nodes.items():
            print(f'{n},{n},{c}', file=fh)
        print('edgedef>node1 VARCHAR,node2 VARCHAR,directed BOOLEAN,label VARCHAR', file=fh)
        for nn, l  in edges.items():
            n1, n2 = nn
            print(f'{n1},{n2},true,{l}', file=fh)

save_gdf('cancel.gdf', cancel_verbs)
save_gdf('cause.gdf', cause_verbs)
save_gdf('rels.gdf', rels_verbs)
save_gdf('same.gdf', same_verbs)

# %% [markdown]
# ## Cancel
#
# ![image.png](attachment:image.png)
#
#
# ## Cause
#
# ![image-2.png](attachment:image-2.png)
